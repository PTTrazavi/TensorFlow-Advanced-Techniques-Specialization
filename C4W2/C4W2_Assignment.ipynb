# %% [markdown]
# # Week 2 Assignment: CIFAR-10 Autoencoder
#
# For this week, you will create a convolutional autoencoder for the [CIFAR10](https://www.tensorflow.org/datasets/catalog/cifar10) dataset. You are free to choose the architecture of your autoencoder provided that the output image has the same dimensions as the input image.
#
# After training, your model should meet loss and accuracy requirements when evaluated with the test dataset. You will then download the model and upload it in the classroom for grading.
#
# Let's begin!

# %% [markdown]
# ***Important:*** *This colab notebook has read-only access so you won't be able to save your changes. If you want to save your work periodically, please click `File -> Save a Copy in Drive` to create a copy in your account, then work from there.*

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import tensorflow_datasets as tfds

from keras.models import Sequential

# %% [markdown]
# ## Load and prepare the dataset
#
# The [CIFAR 10](https://www.tensorflow.org/datasets/catalog/cifar10) dataset already has train and test splits and you can use those in this exercise. Here are the general steps:
#
# * Load the train/test split from TFDS. Set `as_supervised` to `True` so it will be convenient to use the preprocessing function we provided.
# * Normalize the pixel values to the range [0,1], then return `image, image` pairs for training instead of `image, label`. This is because you will check if the output image is successfully regenerated after going through your autoencoder.
# * Shuffle and batch the train set. Batch the test set (no need to shuffle).

# %%
# preprocessing function
def map_image(image, label):
  image = tf.cast(image, dtype=tf.float32)
  image = image / 255.0

  return image, image # dataset label is not used. replaced with the same image input.

# parameters
BATCH_SIZE = 128
SHUFFLE_BUFFER_SIZE = 1024


### START CODE HERE (Replace instances of `None` with your code) ###

# use tfds.load() to fetch the 'train' split of CIFAR-10
train_dataset = tfds.load('cifar10', as_supervised=True, split="train")

# preprocess the dataset with the `map_image()` function above
train_dataset = train_dataset.map(map_image)

# shuffle and batch the dataset
train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)#.repeat()


# use tfds.load() to fetch the 'test' split of CIFAR-10
test_dataset = tfds.load('cifar10', as_supervised=True, split="test")

# preprocess the dataset with the `map_image()` function above
test_dataset = test_dataset.map(map_image)

# batch the dataset
test_dataset = test_dataset.batch(BATCH_SIZE)#.repeat()

### END CODE HERE ###

# %% [markdown]
# ## Build the Model
#
# Create the autoencoder model. As shown in the lectures, you will want to downsample the image in the encoder layers then upsample it in the decoder path. Note that the output layer should be the same dimensions as the original image. Your input images will have the shape `(32, 32, 3)`. If you deviate from this, your model may not be recognized by the grader and may fail.
#
# We included a few hints to use the Sequential API below but feel free to remove it and use the Functional API just like in the ungraded labs if you're more comfortable with it. Another reason to use the latter is if you want to visualize the encoder output. As shown in the ungraded labs, it will be easier to indicate multiple outputs with the Functional API. That is not required for this assignment though so you can just stack layers sequentially if you want a simpler solution.

# %%
# suggested layers to use. feel free to add or remove as you see fit.
from keras.layers import Conv2D, UpSampling2D

# use the Sequential API (you can remove if you want to use the Functional API)
# model = Sequential()

### START CODE HERE ###
# use `model.add()` to add layers (if using the Sequential API)
def encoder(inputs):
  '''Defines the encoder with two Conv2D and max pooling layers.'''
  conv_1 = tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(inputs)
  max_pool_1 = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(conv_1)

  conv_2 = tf.keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(max_pool_1)
  max_pool_2 = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(conv_2)

  return max_pool_2

def bottle_neck(inputs):
  '''Defines the bottleneck.'''
  bottle_neck = tf.keras.layers.Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same')(inputs)
  encoder_visualization = tf.keras.layers.Conv2D(filters=1, kernel_size=(3,3), activation='sigmoid', padding='same')(bottle_neck)

  return bottle_neck, encoder_visualization

def decoder(inputs):
  '''Defines the decoder path to upsample back to the original image size.'''
  conv_1 = tf.keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(inputs)
  up_sample_1 = tf.keras.layers.UpSampling2D(size=(2,2))(conv_1)

  conv_2 = tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(up_sample_1)
  up_sample_2 = tf.keras.layers.UpSampling2D(size=(2,2))(conv_2)

  conv_3 = tf.keras.layers.Conv2D(filters=3, kernel_size=(3,3), activation='sigmoid', padding='same')(up_sample_2)

  return conv_3

def convolutional_auto_encoder():
  '''Builds the entire autoencoder model.'''
  inputs = tf.keras.layers.Input(shape=(32, 32, 3,))
  encoder_output = encoder(inputs)
  bottleneck_output, encoder_visualization = bottle_neck(encoder_output)
  decoder_output = decoder(bottleneck_output)
  
  model = tf.keras.Model(inputs =inputs, outputs=decoder_output)
  return model

model = convolutional_auto_encoder()

### END CODE HERE ###

model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 8, 8, 128)         295040
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 16, 16, 64)        73792
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 32, 32, 3)         1731
# =================================================================
# Total params: 741,379
# Trainable params: 741,379
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Configure training parameters
#
# We have already provided the optimizer, metrics, and loss in the code below.

# %%
# Please do not change the model.compile() parameters
model.compile(optimizer='adam', metrics=['accuracy'], loss='mean_squared_error')

# %% [markdown]
# ## Training
#
# You can now use [model.fit()](https://keras.io/api/models/model_training_apis/#fit-method) to train your model. You will pass in the `train_dataset` and you are free to configure the other parameters. As with any training, you should see the loss generally going down and the accuracy going up with each epoch. If not, please revisit the previous sections to find possible bugs.

# %%
# parameters
train_steps = len(train_dataset) // BATCH_SIZE 
val_steps = len(test_dataset) // BATCH_SIZE

### START CODE HERE ###
model.fit(train_dataset, steps_per_epoch=train_steps, validation_data=test_dataset, validation_steps=val_steps, epochs=200)
### END CODE HERE ###
# Out:
# Epoch 1/200
# 3/3 [==============================] - 1s 48ms/step - loss: 0.0646 - accuracy: 0.3823
# Epoch 2/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0562 - accuracy: 0.3244
# Epoch 3/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0820 - accuracy: 0.3666
# Epoch 4/200
# 3/3 [==============================] - 0s 55ms/step - loss: 0.0560 - accuracy: 0.5004
# Epoch 5/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0566 - accuracy: 0.4418
# Epoch 6/200
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0439 - accuracy: 0.4306
# Epoch 7/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0352 - accuracy: 0.4157
# Epoch 8/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0326 - accuracy: 0.4509
# Epoch 9/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0281 - accuracy: 0.4685
# Epoch 10/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0261 - accuracy: 0.4634
# Epoch 11/200
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0239 - accuracy: 0.5073
# Epoch 12/200
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0242 - accuracy: 0.5926
# Epoch 13/200
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0196 - accuracy: 0.5899
# Epoch 14/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0211 - accuracy: 0.5668
# Epoch 15/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0181 - accuracy: 0.5938
# Epoch 16/200
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0171 - accuracy: 0.6092
# Epoch 17/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0156 - accuracy: 0.6272
# Epoch 18/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0152 - accuracy: 0.6160
# Epoch 19/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0152 - accuracy: 0.6126
# Epoch 20/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0134 - accuracy: 0.6342
# Epoch 21/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0129 - accuracy: 0.6170
# Epoch 22/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0128 - accuracy: 0.6248
# Epoch 23/200
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0120 - accuracy: 0.6437
# Epoch 24/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0120 - accuracy: 0.6381
# Epoch 25/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0113 - accuracy: 0.6105
# Epoch 26/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0110 - accuracy: 0.6645
# Epoch 27/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0107 - accuracy: 0.6486
# Epoch 28/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0149 - accuracy: 0.6423
# Epoch 29/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0133 - accuracy: 0.6831
# Epoch 30/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0139 - accuracy: 0.6675
# Epoch 31/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0123 - accuracy: 0.6714
# Epoch 32/200
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0119 - accuracy: 0.6642
# Epoch 33/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0115 - accuracy: 0.6944
# Epoch 34/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0110 - accuracy: 0.6694
# Epoch 35/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0103 - accuracy: 0.6627
# Epoch 36/200
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0092 - accuracy: 0.7205
# Epoch 37/200
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0099 - accuracy: 0.6846
# Epoch 38/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0094 - accuracy: 0.6992
# Epoch 39/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0086 - accuracy: 0.6918
# Epoch 40/200
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0089 - accuracy: 0.7163
# Epoch 41/200
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0087 - accuracy: 0.7230
# Epoch 42/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0082 - accuracy: 0.7335
# Epoch 43/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0077 - accuracy: 0.7229
# Epoch 44/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0079 - accuracy: 0.7417
# Epoch 45/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0089 - accuracy: 0.7287
# Epoch 46/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0081 - accuracy: 0.7387
# Epoch 47/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0080 - accuracy: 0.7451
# Epoch 48/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0085 - accuracy: 0.7242
# Epoch 49/200
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0077 - accuracy: 0.7605
# Epoch 50/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0079 - accuracy: 0.7305
# Epoch 51/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0073 - accuracy: 0.7583
# Epoch 52/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0071 - accuracy: 0.7416
# Epoch 53/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0077 - accuracy: 0.7357
# Epoch 54/200
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0075 - accuracy: 0.7469
# Epoch 55/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0071 - accuracy: 0.7622
# Epoch 56/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0070 - accuracy: 0.7546
# Epoch 57/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0067 - accuracy: 0.7496
# Epoch 58/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0071 - accuracy: 0.7543
# Epoch 59/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0065 - accuracy: 0.7579
# Epoch 60/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0069 - accuracy: 0.7516
# Epoch 61/200
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0066 - accuracy: 0.7686
# Epoch 62/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0061 - accuracy: 0.7634
# Epoch 63/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0069 - accuracy: 0.7510
# Epoch 64/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0062 - accuracy: 0.7647
# Epoch 65/200
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0089 - accuracy: 0.7565
# Epoch 66/200
# 3/3 [==============================] - 0s 50ms/step - loss: 0.0086 - accuracy: 0.7237
# Epoch 67/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0072 - accuracy: 0.7483
# Epoch 68/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0075 - accuracy: 0.7509
# Epoch 69/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0066 - accuracy: 0.7281
# Epoch 70/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0067 - accuracy: 0.7099
# Epoch 71/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0066 - accuracy: 0.7468
# Epoch 72/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0060 - accuracy: 0.7707
# Epoch 73/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0061 - accuracy: 0.7496
# Epoch 74/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0062 - accuracy: 0.7768
# Epoch 75/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0059 - accuracy: 0.7558
# Epoch 76/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0059 - accuracy: 0.7653
# Epoch 77/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0060 - accuracy: 0.7712
# Epoch 78/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0058 - accuracy: 0.7756
# Epoch 79/200
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0060 - accuracy: 0.7619
# Epoch 80/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0058 - accuracy: 0.7671
# Epoch 81/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0057 - accuracy: 0.7612
# Epoch 82/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0058 - accuracy: 0.7762
# Epoch 83/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0058 - accuracy: 0.7751
# Epoch 84/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0061 - accuracy: 0.7799
# Epoch 85/200
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0057 - accuracy: 0.7743
# Epoch 86/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0057 - accuracy: 0.7632
# Epoch 87/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0054 - accuracy: 0.7768
# Epoch 88/200
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0054 - accuracy: 0.7762
# Epoch 89/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0051 - accuracy: 0.7798
# Epoch 90/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0054 - accuracy: 0.7656
# Epoch 91/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0055 - accuracy: 0.7858
# Epoch 92/200
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0078 - accuracy: 0.7888
# Epoch 93/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0059 - accuracy: 0.7895
# Epoch 94/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0060 - accuracy: 0.7779
# Epoch 95/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0057 - accuracy: 0.7776
# Epoch 96/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0059 - accuracy: 0.7631
# Epoch 97/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0057 - accuracy: 0.7655
# Epoch 98/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0053 - accuracy: 0.7806
# Epoch 99/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0054 - accuracy: 0.7817
# Epoch 100/200
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0052 - accuracy: 0.7629
# Epoch 101/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0052 - accuracy: 0.7754
# Epoch 102/200
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0053 - accuracy: 0.7637
# Epoch 103/200
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0053 - accuracy: 0.7678
# Epoch 104/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0053 - accuracy: 0.7600
# Epoch 105/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0052 - accuracy: 0.7837
# Epoch 106/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0050 - accuracy: 0.7926
# Epoch 107/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0052 - accuracy: 0.7824
# Epoch 108/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0050 - accuracy: 0.7695
# Epoch 109/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0050 - accuracy: 0.7982
# Epoch 110/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0050 - accuracy: 0.7915
# Epoch 111/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0050 - accuracy: 0.7774
# Epoch 112/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0047 - accuracy: 0.7888
# Epoch 113/200
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0044 - accuracy: 0.7817
# Epoch 114/200
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0068 - accuracy: 0.7655
# Epoch 115/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0068 - accuracy: 0.7684
# Epoch 116/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0056 - accuracy: 0.7784
# Epoch 117/200
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0053 - accuracy: 0.7916
# Epoch 118/200
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0056 - accuracy: 0.7766
# Epoch 119/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0054 - accuracy: 0.7665
# Epoch 120/200
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0048 - accuracy: 0.7742
# Epoch 121/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0048 - accuracy: 0.7658
# Epoch 122/200
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0048 - accuracy: 0.7941
# Epoch 123/200
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0050 - accuracy: 0.7693
# Epoch 124/200
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0045 - accuracy: 0.7877
# Epoch 125/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0047 - accuracy: 0.7864
# Epoch 126/200
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0047 - accuracy: 0.7928
# Epoch 127/200
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0046 - accuracy: 0.7820
# Epoch 128/200
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0047 - accuracy: 0.7916
# Epoch 129/200
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0047 - accuracy: 0.8030
# Epoch 130/200
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0046 - accuracy: 0.7853
# Epoch 131/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0042 - accuracy: 0.8022WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 600 batches). You may need to use the repeat() function when building your dataset.
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 600 batches). You may need to use the repeat() function when building your dataset.
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0042 - accuracy: 0.8022

# %% [markdown]
# ## Model evaluation
#
# You can use this code to test your model locally before uploading to the grader. To pass, your model needs to satisfy these two requirements:
#
# * loss must be less than 0.01
# * accuracy must be greater than 0.6

# %%
result = model.evaluate(test_dataset, steps=10)
# Out:
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0045 - accuracy: 0.7867

# %% [markdown]
# If you did some visualization like in the ungraded labs, then you might see something like the gallery below. This part is not required.

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=12Fy-guiP-3tTPfc9IV2nHhqLvs7LwRo6" width="75%" height="75%"/>

# %% [markdown]
# ## Save your model
#
# Once you are satisfied with the results, you can now save your model. Please download it from the Files window on the left and go back to the Submission portal in Coursera for grading.

# %%
model.save('mymodel.h5')

# %% [markdown]
# **Congratulations on completing this week's assignment!**
